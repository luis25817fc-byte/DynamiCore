# %% [markdown]
# <a href="https://colab.research.google.com/github/luis25817fc-byte/DynamiCore/blob/validation-suite-v2/Enterprise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok fastapi uvicorn nest_asyncio

# %%
from pyngrok import ngrok
from fastapi import FastAPI, Request
from fastapi.middleware.cors import CORSMiddleware
import uvicorn
import math
from collections import Counter
import nest_asyncio
import asyncio

# 1. Preparación del ambiente
nest_asyncio.apply()
ngrok.kill()
ngrok.set_auth_token("3Ftxh0jbexL6IEL8yoHG2fRiVLM_HtzMTbfF2SYgY7i1Syrk")

# 2. Definición del API y Motor
class DynamiCore:
    def analyze(self, system: list):
        counts = Counter(system)
        n = len(system)
        entropy = sum(-(c/n) * math.log2(c/n) for c in counts.values())
        mean = sum(system) / n
        variance = sum((x - mean) ** 2 for x in system) / n
        coherence = 1 / (1 + variance)
        basins = {f"basin_{i}": counts[k] for i, k in enumerate(sorted(counts.keys()))}
        return {"entropy": round(entropy, 6), "coherence": round(coherence, 6), "basins": basins, "n": n}

app = FastAPI()
app.add_middleware(CORSMiddleware, allow_origins=["*"], allow_methods=["*"], allow_headers=["*"])

@app.post("/analyze")
async def analyze_system(request: Request):
    data = await request.json()
    engine = DynamiCore()
    return {"status": "success", "results": engine.analyze(data.get("system", []))}

# 3. Lanzamiento compatible con Colab
public_url = ngrok.connect(8000)
print(f"🚀 URL ACTIVA: {public_url.public_url}")

config = uvicorn.Config(app, host="0.0.0.0", port=8000)
server = uvicorn.Server(config)
await server.serve()
# Out:
# 🚀 URL ACTIVA: https://prelaw-stainless-glowworm.ngrok-free.dev
# INFO:     Started server process [9816]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# WARNING:pyngrok.process.ngrok:t=2026-07-04T20:52:14+0000 lvl=warn msg="Stopping forwarder" name=http-8000-94b00680-4168-4b06-b107-18254d8a804f acceptErr="failed to accept connection: Listener closed"
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [9816]

# %%
import requests

# URL que te acaba de dar el servidor
url = "https://prelaw-stainless-glowworm.ngrok-free.dev/analyze"
payload = {"system": [1, 1, 2, 2, 3, 3, 3]}

# Realizamos la prueba final
try:
    response = requests.post(url, json=payload)
    print("--- TODO FUNCIONA PERFECTAMENTE ---")
    print("Respuesta del servidor:")
    print(response.json())
except Exception as e:
    print(f"Error en la petición: {e}")
# Out:
# --- TODO FUNCIONA PERFECTAMENTE ---
# Respuesta del servidor:
# Error en la petición: Expecting value: line 1 column 1 (char 0)

# %%
import requests

# USA LA URL NUEVA QUE TE ACABA DE DAR EL TÚNEL
url = "https://tu-nueva-url-aqui.ngrok-free.dev/analyze"
payload = {"system": [1, 1, 2, 2, 3, 3, 3]}

try:
    response = requests.post(url, json=payload)
    print(f"Código HTTP: {response.status_code}")
    print(f"Respuesta Cruda: {response.text}") # Esto nos dirá el error real
except Exception as e:
    print(f"Error de conexión: {e}")
# Out:
# Código HTTP: 404
# Respuesta Cruda: <!DOCTYPE html>
# <html class="h-full" lang="en-US" dir="ltr">
#   <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-Regular-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-RegularItalic-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-Medium-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-MediumItalic-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
# ...

# %%
from pyngrok import ngrok
from fastapi import FastAPI, Request
from fastapi.middleware.cors import CORSMiddleware
import uvicorn
import math
from collections import Counter
import nest_asyncio

# 1. Preparación forzada
nest_asyncio.apply()
ngrok.kill()
ngrok.set_auth_token("3Ftxh0jbexL6IEL8yoHG2fRiVLM_HtzMTbfF2SYgY7i1Syrk")

# 2. Definición (tu lógica)
class DynamiCore:
    def analyze(self, system: list):
        counts = Counter(system)
        n = len(system)
        entropy = sum(-(c/n) * math.log2(c/n) for c in counts.values())
        mean = sum(system) / n
        variance = sum((x - mean) ** 2 for x in system) / n
        coherence = 1 / (1 + variance)
        basins = {f"basin_{i}": counts[k] for i, k in enumerate(sorted(counts.keys()))}
        return {"entropy": round(entropy, 6), "coherence": round(coherence, 6), "basins": basins, "n": n}

app = FastAPI()
app.add_middleware(CORSMiddleware, allow_origins=["*"], allow_methods=["*"], allow_headers=["*"])

@app.post("/analyze")
async def analyze_system(request: Request):
    data = await request.json()
    return {"status": "success", "results": DynamiCore().analyze(data.get("system", []))}

# 3. Lanzamiento "Anti-RuntimeError"
public_url = ngrok.connect(8000)
print(f"🚀 URL NUEVA: {public_url.public_url}")

config = uvicorn.Config(app, host="0.0.0.0", port=8000)
server = uvicorn.Server(config)
await server.serve()
# Out:
# 🚀 URL NUEVA: https://prelaw-stainless-glowworm.ngrok-free.dev
# INFO:     Started server process [9816]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     189.201.97.241:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     189.201.97.241:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [9816]

# %%
import requests

# Verifica si la ruta base responde al menos
url_base = "https://prelaw-stainless-glowworm.ngrok-free.dev/"
response = requests.get(url_base)
print("Respuesta de la raíz (/):", response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, array_hook, **kw)
#     516             and not use_decimal and not allow_nan and not kw):
# --> 517         return _default_decoder.decode(s)
#     518     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     395             s = str(s, self.encoding)
# --> 396         obj, end = self.raw_decode(s)
#     397         end = _w(s, end).end()
#
# ...

# %%
import requests

url = "https://prelaw-stainless-glowworm.ngrok-free.dev/analyze"
payload = {"system": [1, 1, 2, 2, 3, 3, 3]}
headers = {"Content-Type": "application/json"}

# Usamos POST explícitamente
response = requests.post(url, json=payload, headers=headers)

print(f"Estado: {response.status_code}")
print(f"Respuesta: {response.text}")
# Out:
# Estado: 404
# Respuesta: <!DOCTYPE html>
# <html class="h-full" lang="en-US" dir="ltr">
#   <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-Regular-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-RegularItalic-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-Medium-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://assets.ngrok.com/fonts/euclid-square/EuclidSquare-MediumItalic-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
# ...

# %%
# !echo "web: gunicorn api.main:app -w 4 -k uvicorn.workers.UvicornWorker" > Procfile

# %%
# !pip install sqlalchemy
# !pip install psycopg2-binary
# !pip install passlib[bcrypt]
# !pip install python-jose
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 kB 9.7 MB/s eta 0:00:00
# ...

# %%
# Limpiar si existe algo anterior
# !rm -rf /content/DynamiCore

# Clonar el repositorio
# !git clone https://github.com/luis25817fc-byte/DynamiCore.git

# Entrar al proyecto
# %cd /content/DynamiCore

# Cambiar a la rama donde estamos trabajando
# !git fetch --all
# !git checkout validation-suite-v2

# Verificar
# !git branch
# Out:
# Cloning into 'DynamiCore'...
# remote: Enumerating objects: 1247, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 1247 (delta 78), reused 31 (delta 31), pack-reused 1120 (from 1)
# Receiving objects: 100% (1247/1247), 850.10 KiB | 7.73 MiB/s, done.
# Resolving deltas: 100% (533/533), done.
# /content/DynamiCore
# Fetching origin
# Already on 'validation-suite-v2'
# Your branch is up to date with 'origin/validation-suite-v2'.
# * validation-suite-v2

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

print(ROOT.exists())
# Out:
# True

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

folders = [

    "app/core",
    "app/models",
    "api/routes",
    "app/services",
    "app/schemas",
    "app/utils",
    "app/middleware",
    "frontend/src/components",
    "frontend/src/pages",
    "frontend/src/layout",
    "frontend/src/hooks",
    "frontend/src/services",
    "frontend/src/assets",

]

for folder in folders:

    (ROOT / folder).mkdir(
        parents=True,
        exist_ok=True
    )

print("✅ Enterprise folders created.")
# Out:
# ✅ Enterprise folders created.

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

FILES = [

    "app/core/db.py",
    "app/core/security.py",
    "app/core/auth.py",
    "app/core/analyzer.py",

    "app/models/user.py",
    "app/models/api_key.py",
    "app/models/analysis.py",
    "app/models/subscription.py",

    "api/main.py",

    "api/routes/auth.py",
    "api/routes/users.py",
    "api/routes/dashboard.py",
    "api/routes/analysis.py",

    "frontend/src/App.jsx",
    "frontend/src/pages/Dashboard.jsx",
    "frontend/src/layout/MainLayout.jsx",

]

for f in FILES:

    file = ROOT / f

    file.parent.mkdir(
        parents=True,
        exist_ok=True
    )

    if not file.exists():

        file.write_text(
            "",
            encoding="utf-8"
        )

print("✅ Enterprise Builder V2 Ready")
print(f"📦 {len(FILES)} archivos preparados.")
# Out:
# ✅ Enterprise Builder V2 Ready
# 📦 16 archivos preparados.

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")
TOOLS = ROOT / "tools"
TOOLS.mkdir(parents=True, exist_ok=True)

forge = TOOLS / "forge.py"

forge.write_text("""
from pathlib import Path

ROOT = Path(__file__).resolve().parent.parent

class Forge:

    def write(self, relative_path: str, content: str):

        file = ROOT / relative_path

        file.parent.mkdir(parents=True, exist_ok=True)

        file.write_text(
            content,
            encoding="utf-8"
        )

        print(f"✔ {relative_path}")

forge = Forge()
""", encoding="utf-8")

print("🔥 DynamiCore Forge creado correctamente.")
# Out:
# 🔥 DynamiCore Forge creado correctamente.

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

(ROOT/"tools").mkdir(parents=True, exist_ok=True)

forge = '''
from pathlib import Path

ROOT = Path(__file__).resolve().parent.parent

class Forge:

    def write(self, path, content):

        file = ROOT / path

        file.parent.mkdir(parents=True, exist_ok=True)

        with open(file,"w",encoding="utf-8") as f:
            f.write(content)

        print(f"[OK] {path}")

forge = Forge()
'''

(ROOT/"tools"/"forge.py").write_text(
    forge,
    encoding="utf-8"
)

print("Forge instalado correctamente.")
# Out:
# Forge instalado correctamente.

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

(ROOT/"builders").mkdir(exist_ok=True)

builder = '''
from tools.forge import forge

DB = """\
from sqlalchemy import create_engine
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import sessionmaker
import os

DATABASE_URL=os.getenv(
    "DATABASE_URL",
    "sqlite:///dynamicore.db"
)

engine=create_engine(
    DATABASE_URL,
    pool_pre_ping=True,
    future=True
)

SessionLocal=sessionmaker(
    bind=engine,
    autoflush=False,
    autocommit=False
)

class Base(DeclarativeBase):
    pass

def create_database():
    Base.metadata.create_all(bind=engine)
"""

forge.write(
    "app/core/db.py",
    DB
)

print("Database Enterprise generado.")
'''

(ROOT/"builders"/"builder_database.py").write_text(
    builder,
    encoding="utf-8"
)

print("Builder Database creado.")
# Out:
# Builder Database creado.

# %%
# %cd /content/DynamiCore

import sys

sys.path.append("/content/DynamiCore")

print(sys.path[-1])
# Out:
# /content/DynamiCore
# /content/DynamiCore

# %%
# !touch tools/__init__.py
# !touch builders/__init__.py

# %%
# !python -m builders.builder_database
# Out:
# [OK] app/core/db.py
# Database Enterprise generado.

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

(ROOT/"builders").mkdir(exist_ok=True)

code = r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

SECURITY = """
from datetime import datetime,timedelta
from jose import jwt
from passlib.context import CryptContext
import secrets

SECRET_KEY=secrets.token_hex(64)
ALGORITHM="HS256"
ACCESS_TOKEN_EXPIRE_MINUTES=1440

pwd_context=CryptContext(
    schemes=["bcrypt"],
    deprecated="auto"
)

def hash_password(password:str):
    return pwd_context.hash(password)

def verify_password(password:str,hashed:str):
    return pwd_context.verify(password,hashed)

def create_access_token(data:dict):
    payload=data.copy()
    payload["exp"]=datetime.utcnow()+timedelta(minutes=ACCESS_TOKEN_EXPIRE_MINUTES)
    return jwt.encode(payload,SECRET_KEY,algorithm=ALGORITHM)

def decode_token(token:str):
    return jwt.decode(token,SECRET_KEY,algorithms=[ALGORITHM])

def create_api_key():
    return secrets.token_hex(32)
"""

forge.write(
    "app/core/security.py",
    SECURITY
)

print("Security Enterprise generado.")
'''

(ROOT/"builders"/"builder_security.py").write_text(
    code,
    encoding="utf-8"
)

print("builder_security.py creado")
# Out:
# builder_security.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_security
# Out:
# /content/DynamiCore
# [OK] app/core/security.py
# Security Enterprise generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

AUTH="""
from app.core.security import create_api_key

def register_user(email,password):

    return {
        "email":email,
        "password":password,
        "api_key":create_api_key()
    }

def login(email,password):

    return {
        "success":True,
        "email":email
    }
"""

forge.write(
    "app/core/auth.py",
    AUTH
)

print("Auth Enterprise generado.")
'''

(ROOT/"builders"/"builder_auth.py").write_text(
    code,
    encoding="utf-8"
)

print("builder_auth.py creado")
# Out:
# builder_auth.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_auth
# Out:
# /content/DynamiCore
# [OK] app/core/auth.py
# Auth Enterprise generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

USER="""
from sqlalchemy import Column
from sqlalchemy import Integer
from sqlalchemy import String
from sqlalchemy import DateTime
from sqlalchemy.sql import func

from app.core.db import Base

class User(Base):

    __tablename__="users"

    id=Column(Integer,primary_key=True,index=True)

    email=Column(String(255),unique=True,index=True)

    password=Column(String(255))

    api_key=Column(String(255),unique=True)

    plan=Column(String(50),default="FREE")

    created_at=Column(DateTime(timezone=True),server_default=func.now())
"""

forge.write(
    "app/models/user.py",
    USER
)

print("User model generado.")
'''

(ROOT/"builders"/"builder_user.py").write_text(code,encoding="utf-8")

print("builder_user.py creado")
# Out:
# builder_user.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_user
# Out:
# /content/DynamiCore
# [OK] app/models/user.py
# User model generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

MODEL="""
from sqlalchemy import Column
from sqlalchemy import Integer
from sqlalchemy import Float
from sqlalchemy import ForeignKey
from sqlalchemy import DateTime
from sqlalchemy.sql import func

from app.core.db import Base

class Analysis(Base):

    __tablename__="analysis"

    id=Column(Integer,primary_key=True,index=True)

    user_id=Column(Integer,ForeignKey("users.id"))

    entropy=Column(Float)

    coherence=Column(Float)

    created_at=Column(DateTime(timezone=True),server_default=func.now())
"""

forge.write(
    "app/models/analysis.py",
    MODEL
)

print("Analysis model generado.")
'''

(ROOT/"builders"/"builder_analysis.py").write_text(code,encoding="utf-8")

print("builder_analysis.py creado")
# Out:
# builder_analysis.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_analysis
# Out:
# /content/DynamiCore
# [OK] app/models/analysis.py
# Analysis model generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

MODEL="""
from sqlalchemy import Column
from sqlalchemy import Integer
from sqlalchemy import String
from sqlalchemy import DateTime
from sqlalchemy.sql import func

from app.core.db import Base

class Subscription(Base):

    __tablename__="subscriptions"

    id=Column(Integer,primary_key=True,index=True)

    user_id=Column(Integer)

    plan=Column(String(50))

    status=Column(String(50))

    created_at=Column(DateTime(timezone=True),server_default=func.now())
"""

forge.write(
    "app/models/subscription.py",
    MODEL
)

print("Subscription model generado.")
'''

(ROOT/"builders"/"builder_subscription.py").write_text(code,encoding="utf-8")

print("builder_subscription.py creado")
# Out:
# builder_subscription.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_subscription
# Out:
# /content/DynamiCore
# [OK] app/models/subscription.py
# Subscription model generado.

# %%
from pathlib import Path

ROOT = Path("/content/DynamiCore")

code = r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

API = """
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware

app=FastAPI(
    title="DynamiCore Enterprise",
    version="2.0"
)

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

@app.get("/")

def home():

    return {
        "status":"online",
        "engine":"DynamiCore Enterprise"
    }

@app.get("/health")

def health():

    return {
        "status":"healthy"
    }

@app.get("/version")

def version():

    return {
        "version":"2.0 Enterprise"
    }
"""

forge.write(
    "api/main.py",
    API
)

print("API Enterprise creada.")
'''

(ROOT/"builders"/"builder_api_main.py").write_text(
    code,
    encoding="utf-8"
)

print("builder_api_main.py creado")
# Out:
# builder_api_main.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_api_main
# Out:
# /content/DynamiCore
# [OK] api/main.py
# API Enterprise creada.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

LOGIN="""
from fastapi import APIRouter

router=APIRouter()

@router.post("/login")

def login():

    return {
        "success":True,
        "message":"Login Enterprise OK"
    }
"""

forge.write(
    "api/routes/login.py",
    LOGIN
)

print("Login creado.")
'''

(ROOT/"builders"/"builder_login.py").write_text(code,encoding="utf-8")

print("builder_login.py creado")
# Out:
# builder_login.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_login
# Out:
# /content/DynamiCore
# [OK] api/routes/login.py
# Login creado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

REGISTER="""
from fastapi import APIRouter

router=APIRouter()

@router.post("/register")

def register():

    return {
        "success":True,
        "message":"Usuario registrado."
    }
"""

forge.write(
    "api/routes/register.py",
    REGISTER
)

print("Register creado.")
'''

(ROOT/"builders"/"builder_register.py").write_text(code,encoding="utf-8")

print("builder_register.py creado")
# Out:
# builder_register.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_register
# Out:
# /content/DynamiCore
# [OK] api/routes/register.py
# Register creado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

MODEL="""
from sqlalchemy import Column,Integer,String,ForeignKey
from app.core.db import Base

class APIKey(Base):

    __tablename__="api_keys"

    id=Column(Integer,primary_key=True,index=True)

    user_id=Column(Integer,ForeignKey("users.id"))

    api_key=Column(String(255),unique=True,index=True)

    status=Column(String(50),default="ACTIVE")
"""

forge.write(
    "app/models/api_key.py",
    MODEL
)

print("APIKey model generado.")
'''

(ROOT/"builders"/"builder_apikey.py").write_text(code,encoding="utf-8")

print("builder_apikey.py creado")
# Out:
# builder_apikey.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_apikey
# Out:
# /content/DynamiCore
# [OK] app/models/api_key.py
# APIKey model generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

ROUTE="""
from fastapi import APIRouter

router=APIRouter()

@router.get("/dashboard")

def dashboard():

    return {

        "status":"online",

        "engine":"DynamiCore",

        "users":0,

        "analysis":0,

        "version":"Enterprise"

    }
"""

forge.write(
    "api/routes/dashboard.py",
    ROUTE
)

print("Dashboard Route generado.")
'''

(ROOT/"builders"/"builder_dashboard_route.py").write_text(code,encoding="utf-8")

print("builder_dashboard_route.py creado")
# Out:
# builder_dashboard_route.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_dashboard_route
# Out:
# /content/DynamiCore
# [OK] api/routes/dashboard.py
# Dashboard Route generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

ROUTE="""
from fastapi import APIRouter

router=APIRouter()

@router.post("/analyze")

def analyze():

    return{

        "entropy":0.95,

        "coherence":0.82,

        "prediction":"NORMAL"

    }
"""

forge.write(
    "api/routes/analysis.py",
    ROUTE
)

print("Analysis Route generado.")
'''

(ROOT/"builders"/"builder_analysis_route.py").write_text(code,encoding="utf-8")

print("builder_analysis_route.py creado")
# Out:
# builder_analysis_route.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_analysis_route
# Out:
# /content/DynamiCore
# [OK] api/routes/analysis.py
# Analysis Route generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

ROUTE="""
from fastapi import APIRouter

router=APIRouter()

@router.get("/users")

def users():

    return{

        "total_users":0,

        "free":0,

        "pro":0,

        "enterprise":0

    }
"""

forge.write(
    "api/routes/users.py",
    ROUTE
)

print("Users Route generado.")
'''

(ROOT/"builders"/"builder_users_route.py").write_text(code,encoding="utf-8")

print("builder_users_route.py creado")
# Out:
# builder_users_route.py creado

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_users_route
# Out:
# /content/DynamiCore
# [OK] api/routes/users.py
# Users Route generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

JWT="""
from datetime import datetime,timedelta
from jose import jwt

SECRET_KEY="DYNAMICORE_ENTERPRISE_2026"

ALGORITHM="HS256"

def create_token(email):

    payload={

        "sub":email,

        "exp":datetime.utcnow()+timedelta(days=1)

    }

    return jwt.encode(
        payload,
        SECRET_KEY,
        algorithm=ALGORITHM
    )
"""

forge.write(
    "app/core/jwt.py",
    JWT
)

print("JWT generado.")
'''

(ROOT/"builders"/"builder_jwt.py").write_text(code)

print("builder_jwt listo")
# Out:
# builder_jwt listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_jwt
# Out:
# /content/DynamiCore
# [OK] app/core/jwt.py
# JWT generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class Metrics:

    def __init__(self):

        self.total_users=0

        self.total_analysis=0

        self.total_predictions=0

        self.api_calls=0

    def export(self):

        return{

            "users":self.total_users,

            "analysis":self.total_analysis,

            "predictions":self.total_predictions,

            "api_calls":self.api_calls

        }
"""

forge.write(
    "app/core/metrics.py",
    TXT
)

print("Metrics generado.")
'''

(ROOT/"builders"/"builder_metrics.py").write_text(code)

print("builder_metrics listo")
# Out:
# builder_metrics listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_metrics
# Out:
# /content/DynamiCore
# [OK] app/core/metrics.py
# Metrics generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
from datetime import datetime

def log(message):

    print(

        f"[{datetime.now()}] {message}"

    )
"""

forge.write(
    "app/core/logger.py",
    TXT
)

print("Logger generado.")
'''

(ROOT/"builders"/"builder_logger.py").write_text(code)

print("builder_logger listo")
# Out:
# builder_logger listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_logger
# Out:
# /content/DynamiCore
# [OK] app/core/logger.py
# Logger generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
APP_NAME="DynamiCore Enterprise"

VERSION="2.0"

AI_ENABLED=True

VOICE_ENABLED=False

THREED_ENGINE=False
"""

forge.write(
    "app/core/config.py",
    TXT
)

print("Config generado.")
'''

(ROOT/"builders"/"builder_config.py").write_text(code)

print("builder_config listo")
# Out:
# builder_config listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_config
# Out:
# /content/DynamiCore
# [OK] app/core/config.py
# Config generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
FREE="FREE"
PRO="PRO"
ENTERPRISE="ENTERPRISE"

ROLE_LIMITS={

    FREE:{
        "analysis":100
    },

    PRO:{
        "analysis":10000
    },

    ENTERPRISE:{
        "analysis":999999999
    }

}
"""

forge.write(
"app/core/roles.py",
TXT
)

print("Roles generado.")
'''

(ROOT/"builders"/"builder_roles.py").write_text(code)

print("builder_roles listo")
# Out:
# builder_roles listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_roles
# Out:
# /content/DynamiCore
# [OK] app/core/roles.py
# Roles generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class History:

    def __init__(self):

        self.items=[]

    def add(self,item):

        self.items.append(item)

    def all(self):

        return self.items
"""

forge.write(
"app/core/history.py",
TXT
)

print("History generado.")
'''

(ROOT/"builders"/"builder_history.py").write_text(code)

print("builder_history listo")
# Out:
# builder_history listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_history
# Out:
# /content/DynamiCore
# [OK] app/core/history.py
# History generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
NORMAL="GREEN"

RISK="YELLOW"

WARNING="ORANGE"

CRITICAL="RED"

def predict(score):

    if score<0.3:
        return NORMAL

    if score<0.6:
        return RISK

    if score<0.8:
        return WARNING

    return CRITICAL
"""

forge.write(
"app/core/alerts.py",
TXT
)

print("Alerts generado.")
'''

(ROOT/"builders"/"builder_alerts.py").write_text(code)

print("builder_alerts listo")
# Out:
# builder_alerts listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_alerts
# Out:
# /content/DynamiCore
# [OK] app/core/alerts.py
# Alerts generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class AIEngine:

    def explain(self,result):

        return f"DynamiCore AI: {result}"

    def predict(self,entropy,coherence):

        if coherence>0.9:

            return "Stable"

        if coherence>0.7:

            return "Watch"

        return "Critical"
"""

forge.write(
"app/core/ai_engine.py",
TXT
)

print("AI Engine generado.")
'''

(ROOT/"builders"/"builder_ai_engine.py").write_text(code)

print("builder_ai_engine listo")
# Out:
# builder_ai_engine listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_ai_engine
# Out:
# /content/DynamiCore
# [OK] app/core/ai_engine.py
# AI Engine generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
from app.core.db import Base
from app.core.db import engine

from app.models.user import User
from app.models.analysis import Analysis
from app.models.subscription import Subscription
from app.models.api_key import APIKey

def init_database():

    Base.metadata.create_all(bind=engine)

    print("DynamiCore Database Ready")
"""

forge.write(
"app/core/init_db.py",
TXT
)

print("InitDB generado.")
'''

(ROOT/"builders"/"builder_initdb.py").write_text(code)

print("builder_initdb listo")
# Out:
# builder_initdb listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_initdb
# Out:
# /content/DynamiCore
# [OK] app/core/init_db.py
# InitDB generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class UserService:

    def create(self,email):

        return{

            "email":email,

            "status":"created"

        }

    def delete(self,email):

        return{

            "status":"deleted"

        }

    def list(self):

        return[]
"""

forge.write(
"app/services/users.py",
TXT
)

print("UserService generado.")
'''

(ROOT/"builders"/"builder_userservice.py").write_text(code)

print("builder_userservice listo")
# Out:
# builder_userservice listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_userservice
# Out:
# /content/DynamiCore
# [OK] app/services/users.py
# UserService generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
from app.core.ai_engine import AIEngine

ai=AIEngine()

class AnalysisService:

    def analyze(self,entropy,coherence):

        prediction=ai.predict(
            entropy,
            coherence
        )

        return{

            "entropy":entropy,

            "coherence":coherence,

            "prediction":prediction

        }
"""

forge.write(
"app/services/analysis.py",
TXT
)

print("AnalysisService generado.")
'''

(ROOT/"builders"/"builder_analysisservice.py").write_text(code)

print("builder_analysisservice listo")
# Out:
# builder_analysisservice listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_analysisservice
# Out:
# /content/DynamiCore
# [OK] app/services/analysis.py
# AnalysisService generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class VoiceEngine:

    def speak(self,text):

        return{

            "voice":True,

            "message":text

        }

    def alert(self,text):

        return{

            "type":"voice_alert",

            "message":text

        }
"""

forge.write(
"app/core/voice_engine.py",
TXT
)

print("Voice Engine generado.")
'''

(ROOT/"builders"/"builder_voice_engine.py").write_text(code)

print("builder_voice_engine listo")
# Out:
# builder_voice_engine listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_voice_engine
# Out:
# /content/DynamiCore
# [OK] app/core/voice_engine.py
# Voice Engine generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class PredictionEngine:

    def predict(self,entropy,coherence):

        probability=round(coherence*100,2)

        if coherence>=0.90:

            state="STABLE"

        elif coherence>=0.70:

            state="WARNING"

        else:

            state="CRITICAL"

        return{

            "state":state,

            "probability":probability

        }
"""

forge.write(
"app/core/prediction_engine.py",
TXT
)

print("Prediction Engine generado.")
'''

(ROOT/"builders"/"builder_prediction_engine.py").write_text(code)

print("builder_prediction_engine listo")
# Out:
# builder_prediction_engine listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_prediction_engine
# Out:
# /content/DynamiCore
# [OK] app/core/prediction_engine.py
# Prediction Engine generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
class NotificationEngine:

    def notify(self,title,message):

        return{

            "title":title,

            "message":message,

            "status":"sent"

        }

    def warning(self,message):

        return self.notify(

            "WARNING",

            message

        )

    def critical(self,message):

        return self.notify(

            "CRITICAL",

            message

        )
"""

forge.write(
"app/core/notification_engine.py",
TXT
)

print("Notification Engine generado.")
'''

(ROOT/"builders"/"builder_notification_engine.py").write_text(code)

print("builder_notification_engine listo")
# Out:
# builder_notification_engine listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_notification_engine
# Out:
# /content/DynamiCore
# [OK] app/core/notification_engine.py
# Notification Engine generado.

# %%
from pathlib import Path

ROOT=Path("/content/DynamiCore")

code=r'''
import sys
sys.path.append("/content/DynamiCore")

from tools.forge import forge

TXT="""
COMMAND_CENTER=True

ENABLE_3D=True

ENABLE_WEBGL=True

ENABLE_AI=True

ENABLE_VOICE=True

ENABLE_ALERTS=True

ENABLE_PREDICTION=True

ENABLE_ANIMATIONS=True

ENABLE_TIMELINE=True

ENABLE_GLOBE=True
"""

forge.write(
"app/core/command_center.py",
TXT
)

print("Command Center Config generado.")
'''

(ROOT/"builders"/"builder_command_center.py").write_text(code)

print("builder_command_center listo")
# Out:
# builder_command_center listo

# %%
# %cd /content/DynamiCore
# !python -m builders.builder_command_center
# Out:
# /content/DynamiCore
# [OK] app/core/command_center.py
# Command Center Config generado.
